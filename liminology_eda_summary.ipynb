# %% [markdown]
# This code is for us to explore the data, perform some EDA to understand data's patters, trends and poential issues.

# %%
#Importing lib's
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re

# %%
#Input and Output paths
input_file = r"S:\Sem_4\Output\cleaned_limnology_data.xlsx"
output_dir = r"S:\Sem_4\Output\eda_plots"
summary_file = r"S:\Sem_4\Output\limnology_eda_summary.xlsx"

#Creating a directory for plots, if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
#Loading the cleaned Limnology data
df = pd.read_excel(input_file)

# %%
#Summary statics
summary_stats = df.describe(include='all')
print("Summary stats:")
print(summary_stats)
# Out:
# Summary stats:
#               date            lake_name   site_name    latitude   longitude  \
# count          328                  328         328  307.000000  310.000000
# unique         124                   47          82         NaN         NaN
# top     2024-10-10  kashagawigamog lake  STOC-WQ-01         NaN         NaN
# freq             8                   23          10         NaN         NaN
# mean           NaN                  NaN         NaN   45.074833  -75.432422
# std            NaN                  NaN         NaN    0.162100   21.686530
# min            NaN                  NaN         NaN   44.012210  -78.805910
# 25%            NaN                  NaN         NaN   44.992145  -78.664856
# 50%            NaN                  NaN         NaN   45.063610  -78.435995
# 75%            NaN                  NaN         NaN   45.165075  -78.346655
# max            NaN                  NaN         NaN   45.704940   78.806530
#
#         lake_depth_(in_metres)    air_temp air_moisture cloud_cover  \
# count               325.000000  305.000000          323         325
# unique                     NaN         NaN            8           8
# top                        NaN         NaN          dry       clear
# freq                       NaN         NaN          252         127
# mean                 30.591446   17.565246          NaN         NaN
# std                  16.328821    8.829588          NaN         NaN
# min                   4.500000  -18.000000          NaN         NaN
# 25%                  18.300000   15.300000          NaN         NaN
# 50%                  26.000000   19.200000          NaN         NaN
# 75%                  39.400000   22.700000          NaN         NaN
# max                  88.700000   35.900000          NaN         NaN
#
#        weather_last_24h  ...  alkalinity  secchi_depth    color_disc  \
# count               302  ...  323.000000    300.000000           292
# unique               71  ...         NaN           NaN            11
# top                rain  ...         NaN           NaN  yellow,brown
# freq                 65  ...         NaN           NaN           184
# mean                NaN  ...   48.061920      4.902133           NaN
# std                 NaN  ...   24.260284      1.432725           NaN
# min                 NaN  ...    0.000000      1.570000           NaN
# 25%                 NaN  ...   40.000000      3.927500           NaN
# 50%                 NaN  ...   40.000000      4.725000           NaN
# 75%                 NaN  ...   60.000000      5.912500           NaN
# max                 NaN  ...  120.000000      9.000000           NaN
#
#              depth  total_kjeldahl_nitrogen_(mg/l)  ammonia_(mg/l)  \
# count   256.000000                      321.000000      324.000000
# unique         NaN                             NaN             NaN
# top            NaN                             NaN             NaN
# freq           NaN                             NaN             NaN
# mean      4.854688                        0.285149        0.011627
# std       1.478455                        0.104049        0.011693
# min       1.570000                        0.018900        0.001340
# 25%       3.750000                        0.223000        0.005000
# 50%       4.555000                        0.265000        0.007300
# 75%       6.000000                        0.325000        0.012900
# max       9.000000                        1.310000        0.115000
#
#         nitrate_(mg/l) nitrite_(mg/l)  average_phosphorus_(mg/l)  \
# count       323.000000         141.00                 324.000000
# unique             NaN            NaN                        NaN
# top                NaN            NaN                        NaN
# freq               NaN            NaN                        NaN
# mean          0.038171           0.01                   0.005233
# std           0.052293           0.00                   0.003119
# min           0.019600           0.01                   0.000200
# 25%           0.020000           0.01                   0.003700
# 50%           0.020000           0.01                   0.004600
# 75%           0.032000           0.01                   0.006100
# max           0.594000           0.01                   0.044100
#
#         sulfate_(mg/l)
# count       324.000000
# unique             NaN
# top                NaN
# freq               NaN
# mean          3.231451
# std           0.878247
# min           1.620000
# 25%           2.595000
# 50%           3.140000
# 75%           3.790000
# max           7.250000
#
# [11 rows x 25 columns]

# %%
#Detecting outliers using IQR method for numeric columns
outliers_report = []
for col in df.select_dtypes(include=["float64","int64"]).columns:
    if col not in ['latitude', 'longitude']:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][["lake_name", col]]
        if not outliers.empty:
            outliers_report.append({
                "Column": col,
                "Outlier_Count": len(outliers),
                "Outlier_Details": outliers.to_dict()
            })
            print(f"\nOutlier in {col}:")
            print(outliers)
# Out:
# Outlier in lake_depth_(in_metres):
#             lake_name  lake_depth_(in_metres)
# 116  little hawk lake                    88.0
# 122  little hawk lake                    88.7
# 132        halls lake                    72.0
# 134  little hawk lake                    86.4
# 136        halls lake                    72.1
# 139        halls lake                    75.0
#
# Outlier in air_temp:
#                 lake_name  air_temp
# 4                bob lake      -2.0
# 19             cedar lake     -15.0
# 30            spruce lake      -2.0
# 44              drag lake     -12.0
# 45            spruce lake       4.0
# 59            glamor lake     -18.0
# 64         gooderham lake     -18.0
# 72           growler lake     -14.0
# 80              gull lake      -9.0
# 100       haliburton lake      34.4
# 102       haliburton lake      35.9
# 108       haliburton lake      -5.0
# 149            allen lake     -18.0
# 150  little straggle lake      -8.0
# 151     big straggle lake      -8.0
# 188   kashagawigamog lake      -9.0
# 205         kennisis lake       3.7
# 216  little kennisis lake      -4.0
# 219  little kennisis lake       1.0
# 228  little kennisis lake      -2.0
# 229         kennisis lake       2.0
# 235         koshlong lake      -5.0
# 269           wenona lake      -4.0
# 320         stocking lake       0.9
# 326         stocking lake      -8.0
#
# Outlier in conductivity_(us/cm):
#            lake_name  conductivity_(us/cm)
# 53     farquhar lake                 201.0
# 65    gooderham lake                 220.0
# 109  haliburton lake                 238.0
# 110  haliburton lake                 218.0
# 111  haliburton lake                 267.0
# 112      oblong lake                 218.0
# 296     paudash lake                 233.0
# 297     paudash lake                 495.0
# 298     paudash lake                 210.0
# 308     paudash lake                 295.0
# 309     paudash lake                 323.0
#
# Outlier in ph_meter:
#                 lake_name  ph_meter
# 72           growler lake      9.46
# 197         kennisis lake      6.65
# 198         kennisis lake      5.83
# 206         kennisis lake      6.06
# 212  little kennisis lake      5.93
# 220  little kennisis lake      6.00
# 226         kennisis lake      6.04
#
# Outlier in total_hardness:
#                 lake_name  total_hardness
# 15             cedar lake           100.0
# 34              drag lake            30.0
# 95        haliburton lake            50.0
# 97        haliburton lake           150.0
# 128            halls lake           150.0
# 230  little kennisis lake            20.0
# 231  little kennisis lake            20.0
# 246             long lake            50.0
# 320         stocking lake            20.0
#
# Outlier in alkalinity:
#                 lake_name  alkalinity
# 15             cedar lake       110.0
# 20             cedar lake       100.0
# 26            spruce lake         0.0
# 53          farquhar lake       100.0
# 55         fortescue lake       120.0
# 56         fortescue lake       120.0
# 65         gooderham lake       100.0
# 66         gooderham lake       100.0
# 115            halls lake         0.0
# 117         big hawk lake         0.0
# 118      little hawk lake         0.0
# 119            halls lake         0.0
# 120      little hawk lake         0.0
# 203         kennisis lake         0.0
# 227         kennisis lake         0.0
# 230  little kennisis lake         0.0
# 231  little kennisis lake         0.0
# 232         kennisis lake         0.0
# 233  little kennisis lake         0.0
# 235         koshlong lake         3.0
# 246             long lake       100.0
# 252         miskwabi lake       100.0
# 260         negaunee lake       100.0
# 276           wenona lake       100.0
# 312         redstone lake         0.0
# 313            pelaw lake         0.0
# 314  little redstone lake         0.0
# 321         stocking lake         0.0
#
# Outlier in secchi_depth:
#             lake_name  secchi_depth
# 126  little hawk lake           8.9
# 300      paudash lake           9.0
# 316       bitter lake           9.0
#
# Outlier in total_kjeldahl_nitrogen_(mg/l):
#                 lake_name  total_kjeldahl_nitrogen_(mg/l)
# 18             cedar lake                          0.5580
# 22             davis lake                          0.6870
# 45            spruce lake                          0.5100
# 72           growler lake                          0.4970
# 96        haliburton lake                          0.4980
# 97        haliburton lake                          1.3100
# 98        haliburton lake                          0.6240
# 108       haliburton lake                          0.0189
# 152  little straggle lake                          0.5060
# 174   kashagawigamog lake                          0.7510
# 321         stocking lake                          0.0680
#
# Outlier in ammonia_(mg/l):
#                 lake_name  ammonia_(mg/l)
# 2                bob lake          0.0271
# 4                bob lake          0.0277
# 18             cedar lake          0.0293
# 30            spruce lake          0.0355
# 37              drag lake          0.0348
# 43            spruce lake          0.0258
# 45            spruce lake          0.0577
# 64         gooderham lake          0.0288
# 72           growler lake          0.0320
# 75              gull lake          0.0263
# 76              gull lake          0.0325
# 80              gull lake          0.0301
# 128            halls lake          0.0312
# 150  little straggle lake          0.0885
# 151     big straggle lake          0.0451
# 174   kashagawigamog lake          0.0404
# 186            grass lake          0.0263
# 193             head lake          0.1150
# 199         kennisis lake          0.0265
# 204         kennisis lake          0.0282
# 208  little kennisis lake          0.0540
# 216  little kennisis lake          0.0483
# 219  little kennisis lake          0.0315
# 227         kennisis lake          0.0267
# 228  little kennisis lake          0.0403
# 240            lipsy lake          0.0361
# 241            lipsy lake          0.0390
# 283       east moore lake          0.0271
# 305          paudash lake          0.0280
# 320         stocking lake          0.0564
# 326         stocking lake          0.0296
# 327         stocking lake          0.0345
#
# Outlier in nitrate_(mg/l):
#                 lake_name  nitrate_(mg/l)
# 4                bob lake          0.1200
# 19             cedar lake          0.0580
# 34              drag lake          0.0690
# 36            spruce lake          0.3990
# 37              drag lake          0.0800
# 44              drag lake          0.0900
# 45            spruce lake          0.0661
# 59            glamor lake          0.0640
# 64         gooderham lake          0.0720
# 72           growler lake          0.0670
# 74              gull lake          0.2770
# 76              gull lake          0.5940
# 80              gull lake          0.0830
# 81              gull lake          0.1040
# 82              gull lake          0.1000
# 83              gull lake          0.0970
# 92            oblong lake          0.0650
# 93        haliburton lake          0.0820
# 94        haliburton lake          0.0840
# 108       haliburton lake          0.1180
# 109       haliburton lake          0.0750
# 110       haliburton lake          0.0680
# 112           oblong lake          0.0540
# 130      little hawk lake          0.0670
# 131      little hawk lake          0.0510
# 138      little hawk lake          0.0780
# 139            halls lake          0.0600
# 140      little hawk lake          0.0760
# 149            allen lake          0.0760
# 162         mountain lake          0.0530
# 163         mountain lake          0.0600
# 188   kashagawigamog lake          0.0980
# 196         kennisis lake          0.0680
# 197         kennisis lake          0.1710
# 198         kennisis lake          0.0630
# 202         kennisis lake          0.1120
# 203         kennisis lake          0.0750
# 205         kennisis lake          0.0940
# 206         kennisis lake          0.0620
# 211  little kennisis lake          0.1080
# 212  little kennisis lake          0.0650
# 216  little kennisis lake          0.1020
# 217  little kennisis lake          0.0680
# 219  little kennisis lake          0.0890
# 220  little kennisis lake          0.0540
# 228  little kennisis lake          0.1160
# 229         kennisis lake          0.0830
# 230  little kennisis lake          0.1410
# 231  little kennisis lake          0.1000
# 232         kennisis lake          0.0960
# 233  little kennisis lake          0.1190
# 235         koshlong lake          0.0865
# 241            lipsy lake          0.1370
# 263           wenona lake          0.1790
# 271           wenona lake          0.3800
# 284       east moore lake          0.0780
# 285       east moore lake          0.0530
# 293          paudash lake          0.0880
# 322         stocking lake          0.1780
# 326         stocking lake          0.1110
#
# Outlier in average_phosphorus_(mg/l):
#                 lake_name  average_phosphorus_(mg/l)
# 19             cedar lake                    0.01110
# 30            spruce lake                    0.01040
# 45            spruce lake                    0.01000
# 46              drag lake                    0.01000
# 95        haliburton lake                    0.01080
# 150  little straggle lake                    0.01160
# 151     big straggle lake                    0.01265
# 182             head lake                    0.01220
# 187             head lake                    0.01090
# 197         kennisis lake                    0.01070
# 204         kennisis lake                    0.04410
# 208  little kennisis lake                    0.01700
# 267           wenona lake                    0.01650
# 284       east moore lake                    0.01060
#
# Outlier in sulfate_(mg/l):
#            lake_name  sulfate_(mg/l)
# 245        long lake            5.82
# 283  east moore lake            7.25

# %%
#Histograms for numeric columns

#This is a function to clean the column names as they contain special characters which cannot be used for a file name
def clean_col_name(col):
    return re.sub(r'/', '_', col)

#Create and save all the histogram in the eda_plot folder
for col in df.select_dtypes(include=["float64","int64"]).columns:
    if col not in ['latitude', 'longitude']:
        plt.figure(figsize=(8,8))
        sns.histplot(df[col], bins=30, kde=True)
        plt.title(f"Distribution of {col}")
        plt.xlabel(col)
        plt.ylabel("Count")
        plt.savefig(os.path.join(output_dir, f"{clean_col_name(col)}_histogram.png"))
        plt.close()

# %%
#Create and save all the box plots in the eda_plot folder
for col in df.select_dtypes(include=["float64", "int64"]).columns:
    if col != "lake_name":
        plt.figure(figsize=(12, 6))
        sns.boxplot(x="lake_name", y=col, data=df)
        plt.title(f"{col} by Lake")
        plt.xticks(rotation=90)
        plt.tight_layout()
        plt.savefig(os.path.join(output_dir, f"{clean_col_name(col)}_boxplot_by_lake.png"))
        plt.close()

# %%
#Save summary statistics to Excel
with pd.ExcelWriter(summary_file) as writer:
    summary_stats.to_excel(writer, sheet_name="Summary_Stats")
    if outliers_report:
        outliers_df = pd.DataFrame([
            {"Column": r["Column"], "Outlier_Count": r["Outlier_Count"]}
            for r in outliers_report
        ])
        outliers_df.to_excel(writer, sheet_name="Outliers_Summary", index=False)

print(f"EDA summary saved as {summary_file}")
print(f"Plots saved in {output_dir}")
# Out:
# EDA summary saved as S:\Sem_4\Output\limnology_eda_summary.xlsx
# Plots saved in S:\Sem_4\Output\eda_plots
